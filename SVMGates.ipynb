# %% [markdown]
# # Gates using SVM

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)
X = np.random.randn(200, 2)
print("X:")
print(X[:5])
# Out:
# X:
# [[ 1.76405235  0.40015721]
#  [ 0.97873798  2.2408932 ]
#  [ 1.86755799 -0.97727788]
#  [ 0.95008842 -0.15135721]
#  [-0.10321885  0.4105985 ]]

# %%
y_xor = np.logical_xor(X[:, 0] >0, X[:, 1]>0)

y_and = np.logical_and(X[:, 0] >0, X[:, 1]>0)

y_or = np.logical_or(X[:, 0] >0, X[:, 1]>0)

# %%
def plot_gate(X, y, title):
    plt.title(title)
    plt.scatter(X[y==1, 0], X[y==1, 1], c='b', marker='x', label='1')
    plt.scatter(X[y==0, 0], X[y==0, 1], c='r', marker='x', label='1')
    plt.show()

plot_gate(X, y_xor, "XOR")

# %%
plot_gate(y_and)

# %%
plot_gate(y_or)

# %%
(train_data, test_data, train_labels, test_labels) = train_test_split(X, y_xor, test_size=0.25, random_state=42)

# %%
model = SVC(kernel='poly', degree=2, coef0=1)
model.fit(train_data, train_labels)
# Out:
# SVC(coef0=1, degree=2, kernel='poly')

# %%
print("Classfication Report: ")
print(classification_report(test_labels, model.predict(test_data)))

plot_gate(X, model.predict(X), "Predicted")
# Out:
# Classfication Report:
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96        22
#         True       1.00      0.93      0.96        28
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.96      0.96        50
# weighted avg       0.96      0.96      0.96        50

# %%
def train_gate(y):
    global x
    (train_data, test_data, train_labels, test_labels) = train_test_split(X, y, test_size=0.25, random_state=42) 
    model = SVC(kernel='poly', degree=2, coef0=1)
    model.fit(train_data, train_labels)
    print(classification_report(test_labels, model.predict(test_data)))

# %%
train_gate(y_xor)
train_gate(y_and)
train_gate(y_or)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96        22
#         True       1.00      0.93      0.96        28
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.96      0.96        50
# weighted avg       0.96      0.96      0.96        50
#
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        44
#         True       1.00      1.00      1.00         6
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50
#
#               precision    recall  f1-score   support
#
#        False       0.94      0.94      0.94        16
#         True       0.97      0.97      0.97        34
#
#     accuracy                           0.96        50
#    macro avg       0.95      0.95      0.95        50
# weighted avg       0.96      0.96      0.96        50
