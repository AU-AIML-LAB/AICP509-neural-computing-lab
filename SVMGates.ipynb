#  [ 3.53263578e-01 -8.17998823e-02]
#  [ 5.43331671e-01  5.02787379e-01]
#  [ 5.68528216e-01 -1.75210505e-02]
#  [ 1.24968452e+00  1.75395290e+00]
#  [-6.28914099e-01 -8.96134331e-01]
#  [-1.03760694e+00 -1.46905060e-01]
#  [ 4.31113278e-01  7.19230328e-01]
#  [-2.30501106e-01  1.52771235e-01]
#  [-1.04633296e+00  4.02336615e-03]
#  [ 3.78838193e-01 -2.03549051e-01]
#  [ 7.21702543e-01  7.23216991e-01]
#  [-5.52776785e-01  1.46712543e+00]
#  [ 1.02040179e+00  7.12904835e-01]
#  [ 5.52332518e-01  4.98137622e-01]
#  [ 6.23865509e-01 -1.68827199e-01]
#  [-1.48788125e+00 -1.59305610e-01]
#  [ 2.21542574e+00  2.25007173e-01]
#  [-6.91155820e-01 -3.17424110e-01]
#  [-8.45362770e-01 -2.98873312e+00]
#  [-8.92191492e-01  4.31965531e-01]]

# %%
y_xor = np.logical_xor(X[:, 0] >0, X[:, 1]>0)

y_and = np.logical_and(X[:, 0] >0, X[:, 1]>0)

y_or = np.logical_or(X[:, 0] >0, X[:, 1]>0)

# %%
def plot_gate(y):
    global X
    plt.scatter(X[y==1, 0], X[y==1, 1], c='b', marker='x', label='1')
    plt.scatter(X[y==0, 0], X[y==0, 1], c='r', marker='x', label='1')
    plt.show()

plot_gate(y_xor)

# %%
plot_gate(y_and)

# %%
plot_gate(y_or)

# %%
(train_data, test_data, train_labels, test_labels) = train_test_split(X_xor, y_xor, test_size=0.25, random_state=42)

# %%
model = SVC(kernel='poly', degree=2, coef0=1)
model.fit(train_data, train_labels)
# Out:
# SVC(coef0=1, degree=2, kernel='poly')

# %%
print(classification_report(test_labels, model.predict(test_data)))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96        22
#         True       1.00      0.93      0.96        28
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.96      0.96        50
# weighted avg       0.96      0.96      0.96        50

# %%
def train_gate(y):
    global x
    (train_data, test_data, train_labels, test_labels) = train_test_split(X, y, test_size=0.25, random_state=42) 
    model = SVC(kernel='poly', degree=2, coef0=1)
    model.fit(train_data, train_labels)
    print(classification_report(test_labels, model.predict(test_data)))

# %%
train_gate(y_xor)
train_gate(y_and)
train_gate(y_or)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96        22
#         True       1.00      0.93      0.96        28
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.96      0.96        50
# weighted avg       0.96      0.96      0.96        50
#
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        44
#         True       1.00      1.00      1.00         6
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50
#
#               precision    recall  f1-score   support
#
#        False       0.94      0.94      0.94        16
#         True       0.97      0.97      0.97        34
#
#     accuracy                           0.96        50
#    macro avg       0.95      0.95      0.95        50
# weighted avg       0.96      0.96      0.96        50
